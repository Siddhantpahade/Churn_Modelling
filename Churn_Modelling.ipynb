# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhantpahade/Churn_Modelling/blob/main/Churn_Modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split


# importing tensorflow
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
#reading csv file

file_path = 'Learnbay/dataset/CSV file by Shashank'
df = pd.read_csv(file_path)
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (10000, 14)

# %%
x = data.iloc[: , 3:13]
y = data.iloc[: , 13]

# %%
geography = pd.get_dummies(x["Geography"], drop_first = True)
gender = pd.get_dummies(x["Gender"], drop_first = True)

# %%
x["Geography"].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
X = pd.concat([x, geography, gender ] , axis = 1) 
X.drop(columns = ['Geography' , 'Gender'] , inplace = True)

# %%
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male  Germany  Spain  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2 , random_state = 101)

# %%
# Creating a neural network structure

"""
units - number of neuron in hidden layer
hidden_layer = 3

"""

model = Sequential()

#adding 1st hidden layer1
model.add(Dense(100, activation = 'relu'))

#adding 2nd hidden layer2
model.add(Dense(50, activation = 'sigmoid'))

# adding 3rd hidden layer3
model.add(Dense(25, activation = 'relu'))

# adding output layer
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(optimizer = 'SGD',loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, batch_size = 32, epochs = 50, validation_split = 0.2)
# Out:
# Epoch 1/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4973 - accuracy: 0.7969 - val_loss: 0.4883 - val_accuracy: 0.8037
# Epoch 2/50
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4975 - accuracy: 0.7969 - val_loss: 0.4866 - val_accuracy: 0.8037
# Epoch 3/50
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4973 - accuracy: 0.7969 - val_loss: 0.4866 - val_accuracy: 0.8037
# Epoch 4/50
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4974 - accuracy: 0.7969 - val_loss: 0.4870 - val_accuracy: 0.8037
# Epoch 5/50
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4977 - accuracy: 0.7969 - val_loss: 0.4864 - val_accuracy: 0.8037
# Epoch 6/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4975 - accuracy: 0.7969 - val_loss: 0.4872 - val_accuracy: 0.8037
# Epoch 7/50
# ...
